# %%
import pandas as pd 
import requests
from bs4 import  BeautifulSoup

# %%
webpage= requests.get('https://www.sarkariresult.com/?msclkid=92143538ad0011ec938f5a8b1d8ccfbd').text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    SarkariResult.com : Sarkari Results, Latest Online Form | Result 2022
#   </title>
#   <meta content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2022 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place सरकारी रिजल्ट  " name="description"/>
#   <meta content="Sarkari Result, Sarkari Results, sarkari result 2022,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2022, sarkari result 2021, Sarkari Exam, SarkariResult.com" name="keywords"/>
#   <meta content="general" name="rating"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="global" name="distribution"/>
# ...

# %%
soup.find_all('h1')[0].text
# Out:
# 'Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2022 '

# %%
soup.find_all('h2')
# Out:
# [<h2 class="heading">Sarkari Result : Resources to Help Indians Get Government Jobs (Sarkari Job)</h2>,
#  <h2 class="heading">Why Should I Consider a Government Job?</h2>,
#  <h2 class="heading">What Kind of Government Jobs Can I Get?</h2>,
#  <h2 class="heading">With All the Competition, How Can I Get a Job Working in the Government?</h2>,
#  <h2 class="heading">Sarkari Result 2022 : SarkariResult.Com</h2>,
#  <h2 class="heading">How Competitive Is the Government Job Market?</h2>,
#  <h2 class="heading">Sarkari Exam for Government Jobs</h2>,
#  <h2 class="heading">Sarkari Result 2022</h2>,
#  <h2 class="heading">Sarkari Results for State Level Exams</h2>,
#  <h2 class="heading">Sarkari Naukri for Government Jobs</h2>,
#  <h2 class="heading">Sarkari Result - www sarkari result </h2>,
#  <h2 class="heading">Information about jobs and results in Uttar Pradesh on Sarkari Result UP</h2>,
#  <h2 class="heading">Sarkari Result - Online Application Process</h2>,
# ...

# %%
a=soup.find_all('div', id='post')
len(a)
# Out:
# 8

# %%
web=('https://www.cricbuzz.com/?msclkid=a2203fdead0c11eca628acd6fd3080ce')

# %%
sup=BeautifulSoup(web,'lxml')
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\bs4\__init__.py:431: MarkupResemblesLocatorWarning: "https://www.cricbuzz.com/?msclkid=a2203fdead0c11eca628acd6fd3080ce" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
print(sup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    https://www.cricbuzz.com/?msclkid=a2203fdead0c11eca628acd6fd3080ce
#   </p>
#  </body>
# </html>
